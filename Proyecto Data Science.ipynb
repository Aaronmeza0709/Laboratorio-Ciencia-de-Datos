# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# Proyecto Final de Ciencia de Datos

# %%
Este cuaderno contiene ejemplos y practicas de conceptos fundamentales de Ciencia de Datos.

# %%
## Lenguajes de Ciencia de Datos
- Python  
- R  
- SQL  
- Julia  
- Scala

# %%
## Bibliotecas de Ciencia de Datos
- Pandas  
- NumPy  
- Matplotlib  
- ggplot2  
- Scikit-learn  
- Plotly

# %%
## Herramientas de Ciencia de Datos

| Herramienta | Uso |
|-------------|-----|
| Jupyter Notebook | Crear y ejecutar cuadernos interactivos |
| RStudio | Análisis estadístico y visualización |
| GitHub | Control de versiones y colaboración |
| Tableau | Visualización de datos |

# %%
## Ejemplos de Expresiones Aritméticas
- Suma: 5 + 3  
- Resta: 10 - 2  
- Multiplicación: 4 * 3  
- División: 8 / 2

# %%
# Multiplicación y suma de números
resultado = (5 * 3) + (10 + 2)
print("Resultado de la operación:", resultado)

# %%
# Conversión de minutos a horas
minutos = 150
horas = minutos / 60
print(minutos, "minutos son", horas, "horas")

# %%
# Lista de objetivos
objetivos = ["Aprender Python", "Practicar R", "Crear visualizaciones", "Analizar datos"]
print("Objetivos del proyecto:")
for objetivo in objetivos:
    print("-", objetivo)

# %%
**Autor:** Guillermo Meza

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
